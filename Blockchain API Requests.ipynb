# %%
import requests

url = "https://explorer.helium.foundation/api/accounts"

payload={}
headers = {}

response = requests.get("https://api.helium.io/v1/accounts")

print(response.text)
# Out:
# {"data":[{"staked_balance":0,"sec_nonce":0,"sec_balance":0,"nonce":0,"dc_nonce":0,"dc_balance":0,"block":1395860,"balance":0,"address":"14LPynL3R7faax8gEPJqpoFSeVBKgMAhqZaPQDeyUkF47thKA7p"},{"staked_balance":0,"sec_nonce":0,"sec_balance":0,"nonce":0,"dc_nonce":0,"dc_balance":0,"block":1395860,"balance":0,"address":"14SUu3ne5VqP3W5hFN3vUrWHamfzHXCv7XQmRtTwVyMTVcZ8Z4S"},{"staked_balance":0,"sec_nonce":0,"sec_balance":0,"nonce":0,"dc_nonce":0,"dc_balance":0,"block":1395860,"balance":0,"address":"13MFEPqqtb4w4aspsK6ovQ9P3LM1MHMEkhG8aABH5mZJ6ymHtcT"},{"staked_balance":0,"sec_nonce":0,"sec_balance":0,"nonce":0,"dc_nonce":0,"dc_balance":0,"block":1395860,"balance":605044521,"address":"133co26Pv8jL3EZBwmuLhwaddn2qTp8BDf6zaJEWjpTF5aFS2Sh"},{"staked_balance":0,"sec_nonce":0,"sec_balance":0,"nonce":0,"dc_nonce":0,"dc_balance":0,"block":1395860,"balance":0,"address":"13c9jzg2CxDLfwvrmAGU1YzX1Wb5KZdwrfMJjcGAAVBDAVZFvtU"},{"staked_balance":0,"sec_nonce":0,"sec_balance":0,"nonce":0,"dc_nonce":0,"dc
# ...

# %%
import requests


response = requests.get("https://api.helium.io/v1/accounts/rich")

print(response.text)
# Out:
# {"data":[{"staked_balance":36000000000000,"sec_nonce":0,"sec_balance":0,"nonce":48,"dc_nonce":0,"dc_balance":0,"block":1395864,"balance":976260945018452,"address":"13xUgU5QC1v6SLv3DeTibiV5WwA9af4yTvHRqpmvZ42BPAVXQmi"},{"staked_balance":0,"sec_nonce":0,"sec_balance":0,"nonce":2,"dc_nonce":0,"dc_balance":0,"block":1395864,"balance":579350167717562,"address":"13o6FPDRkYFGQwUxyUr2BCbTJBUW2hRnxTFNWevofxkPBqjzwvZ"},{"staked_balance":0,"sec_nonce":0,"sec_balance":166192196300,"nonce":5,"dc_nonce":0,"dc_balance":0,"block":1395864,"balance":522663706006079,"address":"12yyntxFfPhqXDKuEvmAWABNTRnXtYmcgS33WN4tk5YtyaBLDXo"},{"staked_balance":270000000000000,"sec_nonce":32,"sec_balance":166205166949,"nonce":387,"dc_nonce":0,"dc_balance":0,"block":1395864,"balance":145738046518052,"address":"1398hLeHESZHE5jVtaLAV5fdg2vrUeZEs2B92t7TzeQTtugr8dL"},{"staked_balance":0,"sec_nonce":0,"sec_balance":92340017260,"nonce":1,"dc_nonce":0,"dc_balance":0,"block":1395864,"balance":397243080206238,"address":"135bB
# ...

# %%
import requests


response = requests.get("https://api.helium.io/v1/hotspots/882af62149fffff")

print(response.text)
# Out:
# {"error":"Not Found"}

# %%
import requests


response = requests.get("https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese")

print(response.text)
# Out:
# {"data":{"speculative_nonce":2,"lng":-76.30994030803049,"lat":36.889183620934354,"timestamp_added":"2022-01-08T16:54:42.000000Z","status":{"timestamp":"2022-06-13T08:56:40.792000Z","online":"online","listen_addrs":["/ip4/70.174.99.11/tcp/44158"],"height":1394351},"reward_scale":0.5592803955078125,"payer":"13y2EqUUzyQhQGtDSoXktz8m5jHNSiwAKLTYnHNxZq2uH5GGGym","owner":"13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP","nonce":2,"name":"docile-seaweed-otter","mode":"full","location_hex":"882af62149fffff","location":"8c2af6214926dff","last_poc_challenge":1394909,"last_change_block":1394909,"geocode":{"short_street":"Cedar Ln","short_state":"VA","short_country":"US","short_city":"Norfolk","long_street":"Cedar Lane","long_state":"Virginia","long_country":"United States","long_city":"Norfolk","city_id":"bm9yZm9sa3ZpcmdpbmlhdW5pdGVkIHN0YXRlcw"},"gain":80,"elevation":5,"block_added":1171841,"block":1395871,"address":"112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese"}}

# %%
import requests


response = requests.get("https://console.helium.com/api/v1/devices")

print(response.text)
# Out:
# {"message":"invalid_api_key"}

# %%
import requests


response = requests.get("https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese/rewards")

print(response.text)
# Out:
# {"data":[]}

# %%
import requests


response = requests.get("https://api.helium.io/v1/transactions/J-9ST_X_DjpJBoE_m94KO3VvlSW9utvmEUkWWnQtFMc")

print(response.text)
# Out:
# {"data":{"type":"poc_receipts_v2","time":1655140101,"secret":"AL54kA4RZ-rn6wks_uaV7ncAYffmeUful0FqApjae5a0BIk_-sCdQT8h2O81kmqwHyfrzrfcjMOgiu6FwtFNA0UBaTfjRA1IXGWhxg2LPJo06MOdWSGp0n1OiKA59n4LEjk","path":[{"witnesses":[{"timestamp":1655138790364449677,"snr":10.800000190734863,"signal":-68,"packet_hash":"71NEH0zgvUiPkmESOklemdCyONzTJl21Yub18Fz-_-w","owner":"14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC","location_hex":"882af62327fffff","location":"8c2af623266d9ff","is_valid":false,"invalid_reason":"witness_too_close","gateway":"11K5YrxmxU7kUzJWkMtu8nqup9hWw3HYhgEE8eabdFbCwS1WDnH","frequency":904.5,"datarate":"SF9BW125","channel":3}],"receipt":{"tx_power":35,"timestamp":1655138789866322816,"snr":0.0,"signal":0,"origin":"p2p","gateway":"112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese","frequency":0.0,"datarate":"SF9BW125","data":"y3Q","channel":0},"geocode":{"short_street":"Cedar Ln","short_state":"VA","short_country":"US","short_city":"Norfolk","long_street":"Cedar Lane","long
# ...

# %%
import requests
import json

url = "https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese/rewards/sum?min_time=2022-06-1T01:39:53Z&max_time=2022-06-11T01:39:53Z"
response = requests.get(url)

result = response.text


print(json.dumps(result))
# Out:
# "{\"meta\":{\"min_time\":\"2022-06-01T01:39:00Z\",\"max_time\":\"2022-06-21T01:39:00Z\"},\"data\":{\"total\":0.60431168,\"sum\":60431168,\"stddev\":0.014206275817,\"min\":0.0,\"median\":0.02368655,\"max\":0.0,\"avg\":0.0241724672}}"

# %%
import requests
import json

url_blocks = "https://api.helium.io/v1/blocks"
url = "https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese/rewards/?min_time=-7%20day&bucket=day"

print(json.dumps(requests.get(url_blocks).text))

for x in range(1,8):
    res_dict = json.loads ((requests.get(url)).text)
    print(res_dict["data"])
url.split("&cursor")[0]
url = url + "&cursor=" + res_dict["cursor"]


print (res_dict['cursor'])
print(json.dumps(requests.get(url).text))
print(json.dumps(requests.get(url_cur1).text))
# Out:
# "{\"data\":[{\"transaction_count\":116,\"time\":1656427045,\"snapshot_hash\":\"\",\"prev_hash\":\"n0q9Jp_eyxNTqSRE6saMrwkPzXElb_glUYqI9LvbOSg\",\"height\":1417511,\"hash\":\"MDSw4nV-XFclfcEQH2o950tgFb2PD9xlC7h7BjgvLtk\"},{\"transaction_count\":269,\"time\":1656426995,\"snapshot_hash\":\"\",\"prev_hash\":\"2Y2uIEtv3pyFZAMPHF4xPfy1XVAzafmjIsACBvluTW4\",\"height\":1417510,\"hash\":\"n0q9Jp_eyxNTqSRE6saMrwkPzXElb_glUYqI9LvbOSg\"},{\"transaction_count\":249,\"time\":1656426944,\"snapshot_hash\":\"\",\"prev_hash\":\"_ztDbBPEaF3eGZTS4GJUdvIYXCA0-fcCpVh3hhtetX4\",\"height\":1417509,\"hash\":\"2Y2uIEtv3pyFZAMPHF4xPfy1XVAzafmjIsACBvluTW4\"},{\"transaction_count\":214,\"time\":1656426894,\"snapshot_hash\":\"\",\"prev_hash\":\"-zRY5dJ-hrsdh2POoSyv9JiAWh_OxyBy14FaCZhmb68\",\"height\":1417508,\"hash\":\"_ztDbBPEaF3eGZTS4GJUdvIYXCA0-fcCpVh3hhtetX4\"},{\"transaction_count\":269,\"time\":1656426843,\"snapshot_hash\":\"\",\"prev_hash\":\"nDStFTRNAiBPGTMBhgnmyhnRZRvDtHegPMkUus4UfNA\",\"height\":1417507
# ...

# %%
url = "https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese/rewards/?min_time=-7%20day&bucket=day"
print((requests.get(url)).text)
# Out:
# {"data":[],"cursor":"eyJlbmRfYmxvY2siOjEzOTgyODUsImJsb2NrIjoxNDA4NzAwLCJhbmNob3JfYmxvY2siOjE0MDg3MDB9"}

# %%
url = "https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese/rewards/?min_time=-7%20day&bucket=day"
print(json.dumps((requests.get(url)).text))
# Out:
# "{\"data\":[{\"type\":\"poc_witness\",\"timestamp\":\"2022-06-22T23:31:58.000000Z\",\"hash\":\"r3fs-SC_xyXutE3ymZlBsY0TKGonBw9SR9213ZRWQQA\",\"gateway\":\"112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese\",\"block\":1408943,\"amount\":4588192,\"account\":\"13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP\"}],\"cursor\":\"eyJlbmRfYmxvY2siOjEzOTg1MDUsImJsb2NrIjoxNDA4OTAwLCJhbmNob3JfYmxvY2siOjE0MDg5MDB9\"}"

# %%
import requests
import json
url = "https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese/rewards/?min_time=-53%20week&bucket=day&cursor=eyJlbmRfYmxvY2siOjg4NjMzOSwiYmxvY2siOjE0MTAwMDAsImFuY2hvcl9ibG9jayI6MTQxMDAwMH0"
dict = json.loads((requests.get(url)).text)
print(json.dumps(dict, indent = 2))
# Out:
# {
#   "data": [
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-06-23T06:14:23.000000Z",
#       "hash": "ptLTIh4g6OpRSKGkhyB14lYPDqQ_LbQzom_2SVjigB4",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
#       "block": 1409382,
#       "amount": 1986938,
#       "account": "13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-06-22T23:31:58.000000Z",
#       "hash": "r3fs-SC_xyXutE3ymZlBsY0TKGonBw9SR9213ZRWQQA",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
#       "block": 1408943,
#       "amount": 4588192,
#       "account": "13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-06-22T09:27:27.000000Z",
#       "hash": "vh403uV11GY5_b3wgq3aQAcG0LK1hH-5sa6YL3dFZY0",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
# ...

# %%
url = "https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese/rewards/?min_time=-53%20week&bucket=day&cursor=eyJ0eG4iOiJiWEg5dXdjUWNkdlBmRnJ0YjY1em05b213MFdZMEpuY3AydDVXZGNWRGhjIiwiZW5kX2Jsb2NrIjo4ODYzMzksImJsb2NrIjoxMzI3ODI5LCJhbmNob3JfYmxvY2siOjE0MTAwMDB9"
dict = json.loads((requests.get(url)).text)
print(json.dumps(dict, indent = 2))
# Out:
# {
#   "data": [
#     {
#       "type": "poc_challengee",
#       "timestamp": "2022-04-25T02:38:45.000000Z",
#       "hash": "fd42z7Sse4guvcEagBuuS_bCN7BwZHSAlac0Bd6KzqI",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
#       "block": 1326362,
#       "amount": 381432,
#       "account": "13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-04-24T12:15:45.000000Z",
#       "hash": "YTGJVvsyFlnQUE_GULYTw_2Zsw1fTHJfesalB7aGq5w",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
#       "block": 1325502,
#       "amount": 1254539,
#       "account": "13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP"
#     },
#     {
#       "type": "poc_challengee",
#       "timestamp": "2022-04-24T04:08:16.000000Z",
#       "hash": "oseOTJvK_ABiE83csnSetj2wX5BcBNcWpWN4HGwboPc",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
# ...

# %%
url = "https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese/rewards/?min_time=-53%20week&bucket=day&cursor=eyJ0eG4iOiJGTDJmN0J1OHBsNF8tUVdfSVZMWjRkM3FVeGM4UWtJLXNMY3ZURFp3QThnIiwiZW5kX2Jsb2NrIjo4ODYzMzksImJsb2NrIjoxMjU4ODI4LCJhbmNob3JfYmxvY2siOjE0MTAwMDB9"
dict = json.loads((requests.get(url)).text)
print(json.dumps(dict, indent = 2))
# Out:
# {
#   "data": [
#     {
#       "type": "poc_challengee",
#       "timestamp": "2022-03-08T23:39:33.000000Z",
#       "hash": "NX40uYTCLr2boC0zo4l5bTlHXpFqqMd4yySzVtJ5S8M",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
#       "block": 1258653,
#       "amount": 444853,
#       "account": "13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP"
#     },
#     {
#       "type": "poc_challenger",
#       "timestamp": "2022-03-08T09:13:50.000000Z",
#       "hash": "DPoVnrRNk9m1XSyZu_lQ43YwRHv2GMrJKyAe30EV67M",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
#       "block": 1257824,
#       "amount": 536576,
#       "account": "13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP"
#     },
#     {
#       "type": "poc_challenger",
#       "timestamp": "2022-03-07T11:39:40.000000Z",
#       "hash": "YsS8q4UgxjKH2AlewCDCL9K3UzH49Rb4baGgPgpdfgo",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
# ...

# %%
url = "https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese/rewards/?min_time=-53%20week&bucket=day&cursor=eyJ0eG4iOiJQeDNpeG43Rk1MWkhIallIUDdadVhTUlpZUFRBYzdRbTNiVU9jSDBOVkxVIiwiZW5kX2Jsb2NrIjo4ODYzMzksImJsb2NrIjoxMjI5NDEzLCJhbmNob3JfYmxvY2siOjE0MTAwMDB9"
dict = json.loads((requests.get(url)).text)
print(json.dumps(dict, indent = 2))
# Out:
# {
#   "data": [
#     {
#       "type": "poc_challengee",
#       "timestamp": "2022-02-17T07:36:49.000000Z",
#       "hash": "1g7TaSHJyqKYXq3JjhIvNzyp_Nawtc01SPSvOGMSkc0",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
#       "block": 1229343,
#       "amount": 238261,
#       "account": "13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP"
#     },
#     {
#       "type": "poc_challenger",
#       "timestamp": "2022-02-17T01:14:38.000000Z",
#       "hash": "mJ96O8Pd5jDcS8RxGRxkrtQTdr2FHecNwuoDe4n9wns",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
#       "block": 1228923,
#       "amount": 245759,
#       "account": "13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP"
#     },
#     {
#       "type": "poc_challenger",
#       "timestamp": "2022-02-16T17:09:23.000000Z",
#       "hash": "nZntMKmL9pzaePmSs9qGhra3D-p8ZrjPF-2ohj8En9w",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
# ...

# %%
url = "https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese/rewards/?min_time=-53%20week&bucket=day&cursor=eyJ0eG4iOiIyaWQ3NFliQS1FRVNOdzNkWnFpUjQ2MnN0ZWdlWVBTelpfSTl1X3dkSzNvIiwiZW5kX2Jsb2NrIjo4ODYzMzksImJsb2NrIjoxMjAwMTA0LCJhbmNob3JfYmxvY2siOjE0MTAwMDB9"
dict = json.loads((requests.get(url)).text)
print(json.dumps(dict, indent = 2))
# Out:
# {
#   "data": [
#     {
#       "type": "poc_challenger",
#       "timestamp": "2022-01-26T13:48:31.000000Z",
#       "hash": "lOumO4Gi5hPR33a5--q2VDo_xjZ0voSMbxmMDlkWc2s",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
#       "block": 1199333,
#       "amount": 316958,
#       "account": "13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP"
#     },
#     {
#       "type": "poc_challenger",
#       "timestamp": "2022-01-26T07:45:00.000000Z",
#       "hash": "Vw00onc6BfXT6MmgsLSrmpLW5jJKMe0q0L8SVV0QPXA",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
#       "block": 1198946,
#       "amount": 298531,
#       "account": "13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP"
#     },
#     {
#       "type": "poc_challenger",
#       "timestamp": "2022-01-25T18:51:24.000000Z",
#       "hash": "Kjq7VgNpYMQaGq672t7w8f4MXwl9Ul-m5QzzVeBoYKA",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
# ...

# %%
import requests
import json
url1 = "https://api.helium.io/v1/locations/8c28347213117ff"
dict = json.loads((requests.get(url1)).text)
print(json.dumps(dict, indent = 2))
# Out:
# {
#   "data": {
#     "short_street": "Weyburn Ln",
#     "short_state": "CA",
#     "short_country": "US",
#     "short_city": "San Jose",
#     "long_street": "Weyburn Lane",
#     "long_state": "California",
#     "long_country": "United States",
#     "long_city": "San Jose",
#     "location": "8c28347213117ff",
#     "city_id": "c2FuIGpvc2VjYWxpZm9ybmlhdW5pdGVkIHN0YXRlcw"
#   }
# }

# %%
import requests
import json
import h3
url1 = "https://api.helium.io/v1/locations/8c2af6215b111ff"
dict = json.loads((requests.get(url1)).text)
print(json.dumps(dict, indent = 2))
print(h3.geo_to_h3(36.889183620934, -76.30994030803, 8))
print(h3.h3_to_geo("882ad69b51fffff"))
# Out:
# {
#   "data": {
#     "short_street": "",
#     "short_state": "VA",
#     "short_country": "US",
#     "short_city": "Norfolk",
#     "long_street": "",
#     "long_state": "Virginia",
#     "long_country": "United States",
#     "long_city": "Norfolk",
#     "location": "8c2af6215b111ff",
#     "city_id": "bm9yZm9sa3ZpcmdpbmlhdW5pdGVkIHN0YXRlcw"
#   }
# }
# 882af62323fffff
# (35.78399647812424, -78.62493583588304)

# %%
import requests
import json
url = "https://api.helium.io/v1/transactions/CAncbnIz3ySkZXrwhFTNbAhPAEqkIF7WKZ27oJQiVTU"
dict = json.loads(requests.get(url).text)
print(json.dumps(dict, indent = 2))
# Out:
# {
#   "data": {
#     "type": "poc_receipts_v2",
#     "time": 1656347460,
#     "secret": "AFf8QAc5YX5vHGSzem2XtlOTWkh206HpeAqOkh0ZceJWBLytHWpmh3sjIHyu9eaaGyBKJojK0w9oRVndHjw4tix0c3wpq_MRCjGUuD2bg9wE6MM5zd8PfXEXL3zqlxaXSYU",
#     "path": [
#       {
#         "witnesses": [
#           {
#             "timestamp": 1656346343228416498,
#             "snr": -9.5,
#             "signal": -118,
#             "packet_hash": "9JAgv6fbRJPkXN_SGdoDr-0l16kD_elKXVMHL906tzE",
#             "owner": "13at4u9tvMbLLjz1WSi3okvQH6GSProAbbRxv69RzXEj3sBTToD",
#             "location_hex": "882af62323fffff",
#             "location": "8c2af62323047ff",
#             "is_valid": true,
#             "gateway": "112gAnMkg61VwjjkEEXfsx3HdYZXSiKkQJrEd7PXiURP5B8q6w3A",
#             "frequency": 904.5,
#             "datarate": "SF9BW125",
#             "channel": 3
#           }
#         ],
#         "receipt": {
#           "tx_power": 35,
#           "timestamp": 1656346330986580887,
# ...

# %%
import requests
import json
url = "https://api.helium.io/v1/hotspots/name/docile-seaweed-otter"
dict = json.loads(requests.get(url).text)
print(json.dumps(dict, indent = 2))
# Out:
# {
#   "data": [
#     {
#       "lng": -76.30994030803049,
#       "lat": 36.889183620934354,
#       "timestamp_added": "2022-01-08T16:54:42.000000Z",
#       "status": {
#         "timestamp": "2022-06-24T16:42:04.785000Z",
#         "online": "online",
#         "listen_addrs": [
#           "/ip4/70.174.99.11/tcp/44158"
#         ],
#         "height": 1411479
#       },
#       "reward_scale": 0.5543212890625,
#       "payer": "13y2EqUUzyQhQGtDSoXktz8m5jHNSiwAKLTYnHNxZq2uH5GGGym",
#       "owner": "13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP",
#       "nonce": 2,
#       "name": "docile-seaweed-otter",
#       "mode": "full",
#       "location_hex": "882af62149fffff",
#       "location": "8c2af6214926dff",
#       "last_poc_challenge": 1412436,
#       "last_change_block": 1412467,
#       "geocode": {
#         "short_street": "Cedar Ln",
#         "short_state": "VA",
#         "short_country": "US",
#         "short_city": "Norfolk",
# ...

# %%
import requests
import json
url = "https://api.helium.io/v1/hotspots/location/box/?swlat=36.873774&swlon=-76.322941&nelat=36.900135&nelon=-76.281028"
dict = json.loads(requests.get(url).text)
print(json.dumps(dict, indent = 2))
# Out:
# {
#   "data": [
#     {
#       "lng": -76.29776196781924,
#       "lat": 36.87578266454625,
#       "timestamp_added": "2022-04-05T02:51:02.000000Z",
#       "status": {
#         "timestamp": "2022-06-25T18:31:14.547000Z",
#         "online": "online",
#         "listen_addrs": [
#           "/p2p/116Q5GM2W4sgYPjPgkW2u4mAkBuNuwbGUFkJwB7v684YP3MGaxi/p2p-circuit/p2p/11jnPQyyNprFzrJDbRRm7EN9wEzFsDy5pvr9u6Rabxi9gLGz34N"
#         ],
#         "height": 1413108
#       },
#       "reward_scale": 0.514404296875,
#       "payer": "14eUfY1GsjK4WH6uZYoeagnFtigBKdvPruAXLmc5UsUMEDj3yib",
#       "owner": "145FvPM2pnhdUBY7QSJuR3Bq34uirqbuL22Ffxghhs6d6qBiLrz",
#       "nonce": 1,
#       "name": "loud-lead-yeti",
#       "mode": "full",
#       "location_hex": "882af62337fffff",
#       "location": "8c2af623362ddff",
#       "last_poc_challenge": 1413703,
#       "last_change_block": 1413707,
#       "geocode": {
#         "short_street": "W 27th St",
#         "short_state": "VA",
# ...

# %%
import requests
import json
url = "https://api.helium.io/v1/accounts/137JDkjmtr9xqEVAqyx3y9NtETpSNzWhLQV3XYGUxWrFx8BDU16/activity?filter_types=payment_v2"
dict = json.loads(requests.get(url).text)
print(json.dumps(dict, indent = 2))
# Out:
# {
#   "data": [
#     {
#       "type": "payment_v2",
#       "time": 1656289009,
#       "payments": [
#         {
#           "payee": "137JDkjmtr9xqEVAqyx3y9NtETpSNzWhLQV3XYGUxWrFx8BDU16",
#           "amount": 100000000
#         }
#       ],
#       "payer": "14QXzy8Gj4W4wR1KqMgnScL4ebAK4yVkH9fWTyWxooQYJVXA2cC",
#       "nonce": 1,
#       "height": 1415047,
#       "hash": "rpPBGGeh-DgM4PHHBSzub4iK7zwmLdwccj9I0DFtOnQ",
#       "fee": 35000
#     }
#   ]
# }

# %%
import requests
import json
url = "https://api.helium.io/v1/accounts"
dict = json.loads(requests.get(url).text)
print(json.dumps(dict, indent = 2))
# Out:
# {
#   "data": [
#     {
#       "staked_balance": 0,
#       "sec_nonce": 0,
#       "sec_balance": 0,
#       "nonce": 0,
#       "dc_nonce": 0,
#       "dc_balance": 0,
#       "block": 1415049,
#       "balance": 100000000,
#       "address": "137JDkjmtr9xqEVAqyx3y9NtETpSNzWhLQV3XYGUxWrFx8BDU16"
#     },
#     {
#       "staked_balance": 0,
#       "sec_nonce": 0,
#       "sec_balance": 0,
#       "nonce": 0,
#       "dc_nonce": 0,
#       "dc_balance": 0,
#       "block": 1415049,
#       "balance": 2000000000,
#       "address": "13DkDbFCeLfqZuY1KGBeUS6amvhTC7pQq56ePQ7aAzLWBFxKTKu"
#     },
#     {
#       "staked_balance": 0,
#       "sec_nonce": 0,
#       "sec_balance": 0,
#       "nonce": 0,
#       "dc_nonce": 0,
#       "dc_balance": 0,
#       "block": 1415049,
#       "balance": 1050000000,
#       "address": "13T2KUsFVwD2XmPDtWjNUKKj1tj2FtiaFcWEr5SUK3LpKq3guRN"
#     },
#     {
#       "staked_balance": 0,
#       "sec_nonce": 0,
#       "sec_balance": 0,
# ...

# %%
import requests
import json
url = "https://api.helium.io/v1/accounts/137JDkjmtr9xqEVAqyx3y9NtETpSNzWhLQV3XYGUxWrFx8BDU16/roles/count"
dict = json.loads(requests.get(url).text)
print(json.dumps(dict, indent = 2))
# Out:
# {
#   "data": {
#     "rewards_v2": 0,
#     "oui_v1": 0,
#     "gen_validator_v1": 0,
#     "payment_v1": 0,
#     "poc_request_v1": 0,
#     "consensus_group_v1": 0,
#     "token_burn_exchange_rate_v1": 0,
#     "payment_v2": 1,
#     "validator_heartbeat_v1": 0,
#     "transfer_hotspot_v1": 0,
#     "create_htlc_v1": 0,
#     "transfer_hotspot_v2": 0,
#     "redeem_htlc_v1": 0,
#     "unstake_validator_v1": 0,
#     "stake_validator_v1": 0,
#     "security_coinbase_v1": 0,
#     "transfer_validator_stake_v1": 0,
#     "routing_v1": 0,
#     "assert_location_v2": 0,
#     "rewards_v1": 0,
#     "poc_receipts_v2": 0,
#     "security_exchange_v1": 0,
#     "assert_location_v1": 0,
#     "state_channel_open_v1": 0,
#     "coinbase_v1": 0,
#     "gen_gateway_v1": 0,
#     "token_burn_v1": 0,
#     "consensus_group_failure_v1": 0,
#     "poc_receipts_v1": 0,
#     "vars_v1": 0,
#     "add_gateway_v1": 0,
#     "dc_coinbase_v1": 0,
#     "state_channel_close_v1": 0,
# ...

# %%
import requests
import json
url = "https://api.helium.io/v1/hotspots/location/distance/?lat=36.885343&lon=-76.307307&distance=500"
dict = json.loads(requests.get(url).text)
print(json.dumps(dict, indent = 2))
# Out:
# {
#   "data": [
#     {
#       "lng": -76.30692769417374,
#       "lat": 36.88281961725549,
#       "distance": 281.8904378,
#       "timestamp_added": "2021-11-05T19:38:00.000000Z",
#       "status": {
#         "timestamp": "2022-06-26T18:37:23.616000Z",
#         "online": "online",
#         "listen_addrs": [
#           "/p2p/1129dtYoKZcyZNJbD16ebgXCgeE3Vw59pVy5VHgxy6zTuTV9KVwa/p2p-circuit/p2p/112m6fmmfxUyJMLxqdedBC8cZtwTyHH3oxNcpnuvv1UXAKVm2iCC"
#         ],
#         "height": 1414665
#       },
#       "reward_scale": 0.5518798828125,
#       "payer": "14sKWeeYWQWrBSnLGq79uRQqZyw3Ldi7oBdxbF6a54QboTNBXDL",
#       "owner": "14VGUFrJuCAKi83fxC1vmRxHdtQ2rTYYApWPJqDeJs2BxHPe2wA",
#       "nonce": 2,
#       "name": "polished-cinnabar-ladybug",
#       "mode": "full",
#       "location_hex": "882af62335fffff",
#       "location": "8c2af623349c9ff",
#       "last_poc_challenge": 1413368,
#       "last_change_block": 1413409,
#       "geocode": {
# ...

# %%
import requests
import json
url = "https://api.helium.io/v1/hotspots/hex/882af62149fffff"
dict = json.loads(requests.get(url).text)
print(json.dumps(dict, indent = 2))
# Out:
# {
#   "data": [
#     {
#       "lng": -76.30994030803049,
#       "lat": 36.889183620934354,
#       "timestamp_added": "2022-01-08T16:54:42.000000Z",
#       "status": {
#         "timestamp": "2022-06-24T16:42:04.785000Z",
#         "online": "online",
#         "listen_addrs": [
#           "/ip4/70.174.99.11/tcp/44158"
#         ],
#         "height": 1411479
#       },
#       "reward_scale": 0.5580291748046875,
#       "payer": "13y2EqUUzyQhQGtDSoXktz8m5jHNSiwAKLTYnHNxZq2uH5GGGym",
#       "owner": "13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP",
#       "nonce": 2,
#       "name": "docile-seaweed-otter",
#       "mode": "full",
#       "location_hex": "882af62149fffff",
#       "location": "8c2af6214926dff",
#       "last_poc_challenge": 1414943,
#       "last_change_block": 1414948,
#       "geocode": {
#         "short_street": "Cedar Ln",
#         "short_state": "VA",
#         "short_country": "US",
#         "short_city": "Norfolk",
# ...

# %%
import requests
import json
url = "https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese/rewards/?min_time=2022-02-01&max_time=2022-06-11&cursor=eyJ0eG4iOiJsRTR6RUNwOEROUXh3Yzl6ck9OaGg2OS1jNXg5ODFiaVhNYm9ia2o5clYwIiwiZW5kX2Jsb2NrIjoxMjA2ODY3LCJibG9jayI6MTMxODMyOCwiYW5jaG9yX2Jsb2NrIjoxMzkwODAwfQ"
dict = json.loads(requests.get(url).text)
print(json.dumps(dict, indent = 2))
# Out:
# {
#   "data": [
#     {
#       "type": "poc_challengee",
#       "timestamp": "2022-04-17T15:11:06.000000Z",
#       "hash": "XNGcaZl-PMlLmvFRsAxcemb0s08Lc5Dh13Is0dZdSc8",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
#       "block": 1315705,
#       "amount": 573357,
#       "account": "13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-04-16T03:09:26.000000Z",
#       "hash": "0axWPZZTt1TBXJ_TSaq6Dia6qQo29KXZDCW833Oh2sE",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
#       "block": 1313606,
#       "amount": 2544492,
#       "account": "13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP"
#     },
#     {
#       "type": "poc_challenger",
#       "timestamp": "2022-04-15T09:31:34.000000Z",
#       "hash": "ew30eAlxqwAYF8txVyPbInpiQvcEVbbtCIkaup2Tjps",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
# ...

# %%
import requests
import json
url = "https://api.helium.io/v1/cities/bm9yZm9sa3ZpcmdpbmlhdW5pdGVkIHN0YXRlcw/hotspots"
url2 = "https://api.helium.io/v1/cities/?search=Houston"
dict = json.loads(requests.get(url).text)


print(json.dumps(dict, indent = 2))
print(json.dumps(json.loads(requests.get(url2).text), indent=2))
# Out:
# {
#   "data": [
#     {
#       "lng": -76.25591492059478,
#       "lat": 36.87833009272311,
#       "timestamp_added": "2022-06-25T12:51:17.000000Z",
#       "status": {
#         "timestamp": "2022-06-27T13:16:39.012000Z",
#         "online": "online",
#         "listen_addrs": [
#           "/p2p/112WFjACF325y183zLzCxs48djFMD4x14qJkkM3bGWWefQ39TPFY/p2p-circuit/p2p/11BfWym7vJHJNuS2oARkqYMCtzzZgJ17Cq5zTiseYyo1hhW7Xbt"
#         ],
#         "height": 1415890
#       },
#       "reward_scale": 0.5531005859375,
#       "payer": "14sKWeeYWQWrBSnLGq79uRQqZyw3Ldi7oBdxbF6a54QboTNBXDL",
#       "owner": "14buCmz4ttfoNzPAFBE5kZv8YKTYNwVd5mbtzJh47Ww5V3WgkN9",
#       "nonce": 1,
#       "name": "proper-marmalade-fox",
#       "mode": "full",
#       "location_hex": "882af6231bfffff",
#       "location": "8c2af6231ac4bff",
#       "last_poc_challenge": 1416031,
#       "last_change_block": 1416031,
#       "geocode": {
#         "short_street": "Lens Ave",
#         "short_state": "VA",
# ...

# %%
import requests
import json
url = "https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese/rewards/?min_time=2022-02-02&cursor=eyJlbmRfYmxvY2siOjEzNzc1OTIsImJsb2NrIjoxNDE2ODAwLCJhbmNob3JfYmxvY2siOjE0MTY4MDB9"
dict = json.loads(requests.get(url).text)
print(json.dumps(dict, indent = 2))
# Out:
# {
#   "data": [
#     {
#       "type": "poc_challengee",
#       "timestamp": "2022-06-27T16:43:33.000000Z",
#       "hash": "8n6oHaZCkPzraJvy7k1RMwN3S1tfxPALOXlAc5ib35o",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
#       "block": 1416166,
#       "amount": 536978,
#       "account": "13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-06-26T22:48:28.000000Z",
#       "hash": "nhk_-btyVwEkVpL0KSNvZjmA8z0cLz7SxmbJxPYBmq4",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
#       "block": 1414948,
#       "amount": 5666979,
#       "account": "13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-06-26T08:51:46.000000Z",
#       "hash": "Ci27p1_5d6-9enTALdZ84NCxBb4wnPTciGowxIOVoJE",
#       "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
# ...

# %%
import requests
import json
url = "https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese/activity/?cursor=..."
dict = json.loads(requests.get(url).text)
print(json.dumps(dict, indent = 2))
# Out:
# {
#   "data": [
#     {
#       "type": "rewards_v2",
#       "time": 1656348213,
#       "start_epoch": 1416135,
#       "rewards": [
#         {
#           "type": "poc_challengees",
#           "gateway": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese",
#           "amount": 536978,
#           "account": "13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP"
#         }
#       ],
#       "height": 1416166,
#       "hash": "8n6oHaZCkPzraJvy7k1RMwN3S1tfxPALOXlAc5ib35o",
#       "end_epoch": 1416165
#     },
#     {
#       "type": "poc_receipts_v2",
#       "time": 1656347460,
#       "secret": "AFf8QAc5YX5vHGSzem2XtlOTWkh206HpeAqOkh0ZceJWBLytHWpmh3sjIHyu9eaaGyBKJojK0w9oRVndHjw4tix0c3wpq_MRCjGUuD2bg9wE6MM5zd8PfXEXL3zqlxaXSYU",
#       "path": [
#         {
#           "witnesses": [
#             {
#               "timestamp": 1656346343228416498,
#               "snr": -9.5,
#               "signal": -118,
# ...

# %%
import requests
import json
url = "https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese/activity/?cursor=..."
##url2 = "https://api.helium.io/v1/transactions/8n6oHaZCkPzraJvy7k1RMwN3S1tfxPALOXlAc5ib35o"
dict = json.loads(requests.get(url).text)
print(requests.get(url).text)
print(json.dumps(dict, indent = 2)["data"][0])
# Out:
# {"data":[{"type":"rewards_v2","time":1656348213,"start_epoch":1416135,"rewards":[{"type":"poc_challengees","gateway":"112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese","amount":536978,"account":"13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP"}],"height":1416166,"hash":"8n6oHaZCkPzraJvy7k1RMwN3S1tfxPALOXlAc5ib35o","end_epoch":1416165},{"type":"poc_receipts_v2","time":1656347460,"secret":"AFf8QAc5YX5vHGSzem2XtlOTWkh206HpeAqOkh0ZceJWBLytHWpmh3sjIHyu9eaaGyBKJojK0w9oRVndHjw4tix0c3wpq_MRCjGUuD2bg9wE6MM5zd8PfXEXL3zqlxaXSYU","path":[{"witnesses":[{"timestamp":1656346343228416498,"snr":-9.5,"signal":-118,"packet_hash":"9JAgv6fbRJPkXN_SGdoDr-0l16kD_elKXVMHL906tzE","owner":"13at4u9tvMbLLjz1WSi3okvQH6GSProAbbRxv69RzXEj3sBTToD","location_hex":"882af62323fffff","location":"8c2af62323047ff","is_valid":true,"gateway":"112gAnMkg61VwjjkEEXfsx3HdYZXSiKkQJrEd7PXiURP5B8q6w3A","frequency":904.5,"datarate":"SF9BW125","channel":3}],"receipt":{"tx_power":35,"timestamp":1656346330986580887,"snr":0.0,
# ...

# %% [markdown]
# # start of nodes
# - note1
# - note2
# 6/26: Hotspot Location Box Search (under "Hotspots" in the Blockchain API): to find all hotspots in a square area given (4 coordinates)
#       Activity for Account (under "Accounts" in the Blockchain API): fetches transactions for an account
#       Hotspot Location Distance Search: fetches hotspots within a certain distance from the selected latitude/longitude (under "Hotspots")
#       Hotspots for H3 Index - fetches all the hotspots in a given node(hex) (under "Hotspots")
# 6/27: List Hotspots for a City under "Cities" in Blockchain API: find all hotspots for a given city
#
# *We need type, amount, timestamp for each hotspot
# *json.loads from a file on a local machine
# *data transfer rewards for hotspots-> goal

# %%
import pandas as pd
pd.__version__

df = pd.DataFrame(
    [[4, 7, 10],
     [5, 8, 11],
     [6, 9, 12]],
    index=[1, 2, 3],
    columns=['a', 'b', 'c'])
