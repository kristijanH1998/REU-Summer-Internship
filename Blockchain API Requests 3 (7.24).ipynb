# %%
# This program gives a ranking of all the hotspots withing a selected perimeter based on their HNT earnings from mining

import time
import requests
import json
from matplotlib import pyplot as plt

dict1 = {}
dict2 = {}

url = "https://api.helium.io/v1/hotspots/location/distance/?lat=36.871342&lon=-76.278701&distance=1000"
dict1 = json.loads(requests.get(url).text)
dict2 = dict1
while "cursor" in dict1:
    cursor = dict1['cursor']
    url = "https://api.helium.io/v1/hotspots/location/distance/?lat=36.871342&lon=-76.278701&distance=1000"
    url = url + "&cursor=" + cursor
    dict1 = json.loads(requests.get(url).text)
    dict2.update(dict1)
    time.sleep(1)
url = ''

hotspots = {}
for num in range(len(dict1['data'])):
    hotspots[dict1['data'][num]['address']] = [dict1['data'][num]['name']]
    
addresses = []
for i in range(len(dict1['data'])):
    addresses.append([dict1['data'][i]['address']])   

for a in addresses:

    url = "https://api.helium.io/v1/hotspots/" + a[0] + "/rewards/sum/?min_time=2022-06-23T00:00:01Z&max_time=2022-07-23T23:59:59Z"
    dict = json.loads(requests.get(url).text)
    time.sleep(1)
    while "cursor" in dict:
        hotspots[a[0]].append(dict['data']['total'])
        #print(hotspots[a[0]][1])
        cursor = dict['cursor']
        url = "https://api.helium.io/v1/hotspots/" + a[0] + "/rewards/sum/?min_time=2022-06-23T00:00:01Z&max_time=2022-07-23T23:59:59Z"
        url = url + "&cursor=" + cursor
        dict = json.loads(requests.get(url).text)
        time.sleep(1)
    else:
        hotspots[a[0]].append(dict['data']['total'])
        #print(hotspots[a[0]][1])

# print(json.dumps(hotspots, indent = 2))
dict1 = {k: v for k, v in sorted(hotspots.items(), key=lambda item: item[1][1])}
print(json.dumps(dict1, indent = 2))

i = 1

print("Ranking (HNT earned from mining; highest to lowest): ")
for key, value in reversed(dict1.items()):
    print('%d:' % i, value[0], ': ', value[1])
    i += 1

dict.clear()
dict1.clear()
dict2.clear()
url = ''
# Out:
# {
#   "11yWfEwtSGLw3Vdh4iWgqnuKXRxELUkwN2v5wmB32UaRkq2YQWE": [
#     "early-mocha-otter",
#     0.0
#   ],
#   "113rdGpZkFNybwdZTi9B2o1GbysioAV4btPDX5uM2zfNcKDhfvQ": [
#     "round-fuzzy-beetle",
#     0.0
#   ],
#   "11xjpEDQHL1WirxNZcZ8GiEyb5JzYsqB7QeoAHAu5Km6z2oaEhr": [
#     "cold-vinyl-huskie",
#     0.0
#   ],
#   "112Yj9qQfbYWzNRoWz72V8fW5wrvxbEjmZ4CmTVZE3X4Qr3CJVsQ": [
#     "flaky-eggshell-pike",
#     0.0
#   ],
#   "112XvQnj9s1zSDY7qiHQxCQh5bcx347SUCzudsk159c3s7DL41GZ": [
#     "witty-bamboo-okapi",
#     0.0
#   ],
#   "11KNMkTZz4wzMuYoNih8rB1peudicU9JEiPSKbGoBSMXeYmKsow": [
#     "boxy-peanut-salmon",
#     0.0
#   ],
#   "112VHjzqYK9UF3yaT6nXjsh4BVU4yXjfh71AirkJuJJe64g6YEeq": [
#     "perfect-mango-cyborg",
#     0.0
#   ],
#   "11nJQ7yHckvft38FL6UvyE6rF9ttzqGif37fobEsH7go9ViH2ra": [
#     "stale-malachite-giraffe",
#     0.0
#   ],
#   "115qHpXjkMTeNuFw28WjMdxxSg9UeiZCpvDi4eTW4FvgvQi1VpA": [
#     "tricky-seafoam-sealion",
#     0.0
#   ],
#   "11CURcXMcmSy5Tu8S7mNh2ZLWvmWoo7UYngWD3Wn9ucz5aLv4Ja": [
#     "tall-hazelnut-penguin",
#     0.38678944
#   ],
#   "11p7RvkByMskRcxBEPGdffd1aQAqMnmnUWZJteRiBFyHKHXbvPn": [
#     "immense-banana-cyborg",
#     2.40996376
#   ],
#   "112hULKtpghs6VetJ73CTBPc8yhmQCqLJiNXuApAtmEdjvmNEJQ2": [
#     "sunny-vinyl-urchin",
#     3.74329843
#   ],
#   "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w": [
#     "mini-steel-weasel",
#     4.35527253
#   ]
# }
# Ranking (HNT earned from mining; highest to lowest):
# 1: mini-steel-weasel :  4.35527253
# 2: sunny-vinyl-urchin :  3.74329843
# 3: immense-banana-cyborg :  2.40996376
# 4: tall-hazelnut-penguin :  0.38678944
# 5: tricky-seafoam-sealion :  0.0
# 6: stale-malachite-giraffe :  0.0
# 7: perfect-mango-cyborg :  0.0
# 8: boxy-peanut-salmon :  0.0
# 9: witty-bamboo-okapi :  0.0
# 10: flaky-eggshell-pike :  0.0
# 11: cold-vinyl-huskie :  0.0
# 12: round-fuzzy-beetle :  0.0
# 13: early-mocha-otter :  0.0
