# %% [markdown]
# import pandas as pd
#
#
# df = pd.DataFrame(
# [[4, 7, 10],
# [5, 8, 11],
# [6, 9, 12]],
# index=[1, 2, 3],
# columns=['a', 'b', 'c'])
# print (df)
#
# df2 = pd.DataFrame(
#     {"a" : [4 ,5, 6],
#      "b" : [7, 8, 9],
#      "c" : [10, 11, 12],
#      "d" : [1,2,3]},
# index = pd.MultiIndex.from_tuples(
#     [('d', 1), ('d', 2),
#      ('e', 2)], names=['n', 'v']))
# print(df2)
# pd.concat([df, df2])
# df['Volume'] = df.a*df.b*df.c
# print(df)
# df.plot.scatter(x='a',y='b')
#
# df3 = pd.DataFrame([[5.1, 3.5, 0], [4.9, 3.0, 0], [7.0, 3.2, 1],
#                     [6.4, 3.2, 1], [5.9, 3.0, 2]],
#                    columns=['length', 'width', 'species'])
# print(df3)
# ax1 = df3.plot.scatter(x='length',
#                        y='width',
#                        c='Red')

# %%
import requests
import json

# Code in ln 5-12 loops over cursors
# url = "https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese/activity/?cursor=..."
# dict = json.loads(requests.get(url).text)
# print(json.dumps(dict, indent = 2))

##while(dict['cursor']):
    ##url = "https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese/activity/?" + "cursor=" + dict['cursor']
    ##dict = json.loads(requests.get(url).text)
    ##print(json.dumps(dict, indent = 2))
    
# url = "https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese/roles/?cursor=..."
# dict = json.loads(requests.get(url).text)
# print(json.dumps(dict, indent = 2))

# url = "https://api.helium.io/v1/hotspots/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese/activity/?filter_types=rewards_v2&cursor=eyJ0eXBlcyI6WyJyZXdhcmRzX3YyIl0sIm1pbl9ibG9jayI6MTE3MTg0MSwibWF4X2Jsb2NrIjoxNDI1NjcxLCJibG9jayI6MTQyNTYwMCwiYW5jaG9yX2Jsb2NrIjoxNDI1NjAwfQ"
# dict = json.loads(requests.get(url).text)
# print(json.dumps(dict, indent = 2))


# url = "https://api.helium.io/v1/hotspots/11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w/roles/count"
# dict = json.loads(requests.get(url).text)
# print(json.dumps(dict["data"]["state_channel_close_v1"], indent = 2))
# print(json.dumps(dict["data"], indent = 2))

url = "https://api.helium.io/v1/hotspots/location/distance/?lat=36.885343&lon=-76.307307&distance=500"
dict1 = json.loads(requests.get(url).text)
print(json.dumps(dict1, indent = 2))

the_list = []
for i in range(len(dict1['data'])):
    the_list.append(dict1['data'][i]['address']) 
print(the_list)











url = "https://api.helium.io/v1/hotspots/11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w/activity/?filter_types=state_channel_close_v1&min_time=2022-07-05T00:00:01Z&max_time=2022-07-12T23:59:59Z"
dict = json.loads(requests.get(url).text)

if "cursor" in dict:
    url = "https://api.helium.io/v1/hotspots/11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w/activity/?filter_types=state_channel_close_v1&&" + "cursor=" + dict['cursor']
    dict = json.loads(requests.get(url).text)
else:
    for i in range(len(dict['data'])):
        sum = sum + dict['data'][i]['state_channel']['summaries'][0]['num_packets']

sum = 0
while "cursor" in dict:

    for i in range(len(dict['data'])):
        sum = sum + dict['data'][i]['state_channel']['summaries'][0]['num_packets']
    url = "https://api.helium.io/v1/hotspots/11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w/activity/?filter_types=state_channel_close_v1&min_time=2022-07-05T00:00:01Z&max_time=2022-07-12T23:59:59Z&" + "cursor=" + dict['cursor']
    dict = json.loads(requests.get(url).text)

if "cursor" not in dict:
    for i in range(len(dict['data'])):
        sum = sum + dict['data'][i]['state_channel']['summaries'][0]['num_packets']

# for i in range(len(dict['data'])):
#     print(dict['data'][i]['state_channel']['summaries'][0]['num_packets'])

dict.clear()

print("Total packets transferred: %3d" %(sum))
print("DCs earned: %3d" %(sum))
print("Bytes transferred: %3d" %(sum * 24))
# Out:
# {
#   "data": [
#     {
#       "lng": -76.30692769417374,
#       "lat": 36.88281961725549,
#       "distance": 281.8904378,
#       "timestamp_added": "2021-11-05T19:38:00.000000Z",
#       "status": {
#         "timestamp": "2022-07-07T01:43:38.952000Z",
#         "online": "offline",
#         "listen_addrs": [
#           "/ip4/71.206.164.143/tcp/44158"
#         ],
#         "height": 1428617
#       },
#       "reward_scale": 0.5518798828125,
#       "payer": "14sKWeeYWQWrBSnLGq79uRQqZyw3Ldi7oBdxbF6a54QboTNBXDL",
#       "owner": "14VGUFrJuCAKi83fxC1vmRxHdtQ2rTYYApWPJqDeJs2BxHPe2wA",
#       "nonce": 2,
#       "name": "polished-cinnabar-ladybug",
#       "mode": "full",
#       "location_hex": "882af62335fffff",
#       "location": "8c2af623349c9ff",
#       "last_poc_challenge": 1429302,
#       "last_change_block": 1429305,
#       "geocode": {
#         "short_street": "W 42nd St",
#         "short_state": "VA",
#         "short_country": "US",
#         "short_city": "Norfolk",
#         "long_street": "West 42nd Street",
#         "long_state": "Virginia",
#         "long_country": "United States",
#         "long_city": "Norfolk",
#         "city_id": "bm9yZm9sa3ZpcmdpbmlhdW5pdGVkIHN0YXRlcw"
#       },
#       "gain": 40,
#       "elevation": 5,
#       "block_added": 1085952,
#       "block": 1437147,
#       "address": "112m6fmmfxUyJMLxqdedBC8cZtwTyHH3oxNcpnuvv1UXAKVm2iCC"
#     },
#     {
#       "lng": -76.30385440413401,
#       "lat": 36.88276471938817,
#       "distance": 419.96596311,
#       "timestamp_added": "2021-10-22T18:19:14.000000Z",
#       "status": {
#         "timestamp": "2022-07-09T23:16:19.717000Z",
#         "online": "online",
#         "listen_addrs": [
#           "/p2p/112GJ2i98kaRFpAjY7UcU42rqRx28BDDiATu9tHBHHy6g1Hyn13J/p2p-circuit/p2p/112j53ANZ3FVdDAVYEaXBKsPfBtu59kqdqjqHxTe4hEfD4mGvj2T"
#         ],
#         "height": 1433527
#       },
#       "reward_scale": 0.561798095703125,
#       "payer": "13ENbEQPAvytjLnqavnbSAzurhGoCSNkGECMx7eHHDAfEaDirdY",
#       "owner": "13fm7Rde5v4jLdbU7Sa6psk8gQFHp1CPpykyjLUDYQhz4UCzTQt",
#       "nonce": 4,
#       "name": "attractive-ceramic-opossum",
#       "mode": "full",
#       "location_hex": "882af62335fffff",
#       "location": "8c2af623341e7ff",
#       "last_poc_challenge": 1437059,
#       "last_change_block": 1437062,
#       "geocode": {
#         "short_street": "W 42nd St",
#         "short_state": "VA",
#         "short_country": "US",
#         "short_city": "Norfolk",
#         "long_street": "West 42nd Street",
#         "long_state": "Virginia",
#         "long_country": "United States",
#         "long_city": "Norfolk",
#         "city_id": "bm9yZm9sa3ZpcmdpbmlhdW5pdGVkIHN0YXRlcw"
#       },
#       "gain": 23,
#       "elevation": 5,
#       "block_added": 1065670,
#       "block": 1437147,
#       "address": "112j53ANZ3FVdDAVYEaXBKsPfBtu59kqdqjqHxTe4hEfD4mGvj2T"
#     },
#     {
#       "lng": -76.30994030803049,
#       "lat": 36.889183620934354,
#       "distance": 486.82674321,
#       "timestamp_added": "2022-01-08T16:54:42.000000Z",
#       "status": {
#         "timestamp": "2022-07-12T09:39:56.857000Z",
#         "online": "online",
#         "listen_addrs": [
#           "/ip4/70.174.99.11/tcp/44158",
#           "/p2p/11pBydpTFx3ghgjGrXxAzWACwei2EPtfuTwmJCYyfrY9vLZomps/p2p-circuit/p2p/112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese"
#         ],
#         "height": 1436687
#       },
#       "reward_scale": 0.5694732666015625,
#       "payer": "13y2EqUUzyQhQGtDSoXktz8m5jHNSiwAKLTYnHNxZq2uH5GGGym",
#       "owner": "13KVjsekgBRqjbzsfk3f7QV9ERUHeWZncrP7WkUwxWuWnJr21XP",
#       "nonce": 2,
#       "name": "docile-seaweed-otter",
#       "mode": "full",
#       "location_hex": "882af62149fffff",
#       "location": "8c2af6214926dff",
#       "last_poc_challenge": 1437120,
#       "last_change_block": 1437126,
#       "geocode": {
#         "short_street": "Cedar Ln",
#         "short_state": "VA",
#         "short_country": "US",
#         "short_city": "Norfolk",
#         "long_street": "Cedar Lane",
#         "long_state": "Virginia",
#         "long_country": "United States",
#         "long_city": "Norfolk",
#         "city_id": "bm9yZm9sa3ZpcmdpbmlhdW5pdGVkIHN0YXRlcw"
#       },
#       "gain": 80,
#       "elevation": 5,
#       "block_added": 1171841,
#       "block": 1437147,
#       "address": "112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese"
#     }
#   ]
# }
# ['112m6fmmfxUyJMLxqdedBC8cZtwTyHH3oxNcpnuvv1UXAKVm2iCC', '112j53ANZ3FVdDAVYEaXBKsPfBtu59kqdqjqHxTe4hEfD4mGvj2T', '112kB6UPkSyNhtVs52mbbfB8bemL5WwyRgBR53L96Ld6agHZyese']
# Total packets transferred:  94
# DCs earned:  94
# Bytes transferred: 2256

# %%
# <!---
# This program outputs the number of data packets transferred on a weekly basis through all the hotspots in a selected perimeter
# -->

import pandas as pd
import time
from datetime import date, timedelta
import requests
import json
from matplotlib import pyplot as plt

url = "https://api.helium.io/v1/hotspots/location/distance/?lat=36.871342&lon=-76.278701&distance=200"
dict1 = json.loads(requests.get(url).text)
# print(json.dumps(dict1, indent = 2))

minTime = []
maxTime = []
current_date = date.today()

for i in range(1,10):
    maxTime.append(current_date)
    priorDate = current_date-timedelta(days=7)
    minTime.append(priorDate)
    current_date = priorDate    


dataPerAddress = {}
for i in range(len(dict1['data'])):
    dataPerAddress[dict1['data'][i]['address']] = []
print(dataPerAddress.keys())

sum1 = 0
# sum2 = 0
# sum3 = 0
cursor = ''
for a in dataPerAddress:
    print("Current address: ", a)
    for t in range(len(minTime)):            
        url = "https://api.helium.io/v1/hotspots/"+a+"/activity/?filter_types=state_channel_close_v1&min_time="+str(minTime[t])+"T00:00:01Z&max_time="+str(maxTime[t])+"T23:59:59Z"
        dict = json.loads(requests.get(url).text)
        time.sleep(1)
        while "cursor" in dict:
            for i in range(len(dict['data'])):            
                sum1 = sum1 + dict['data'][i]['state_channel']['summaries'][0]['num_packets']
            cursor = dict['cursor']
            url = "https://api.helium.io/v1/hotspots/"+a+"/activity/?filter_types=state_channel_close_v1&min_time="+str(minTime[t])+"T00:00:01Z&max_time="+str(maxTime[t])+"T23:59:59Z"
            url = url + "&cursor=" + cursor
            dict = json.loads(requests.get(url).text)
            time.sleep(1)
        else:
            for i in range(len(dict['data'])):            
                sum1 = sum1 + dict['data'][i]['state_channel']['summaries'][0]['num_packets']

        dataPerAddress[a].append(sum1)
        sum1 = 0
    dataPerAddress[a].reverse()
    print(dataPerAddress[a])
    plt.plot(dataPerAddress[a])
    plt.show()
    plt.bar(range(9), dataPerAddress[a])
    plt.show()

        
dict.clear()
sum1=0
cursor=''
# Out:
# dict_keys(['11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w', '11yWfEwtSGLw3Vdh4iWgqnuKXRxELUkwN2v5wmB32UaRkq2YQWE'])
# Current address:  11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w
# [81, 49, 52, 141, 263, 197, 85, 31, 94]
# Current address:  11yWfEwtSGLw3Vdh4iWgqnuKXRxELUkwN2v5wmB32UaRkq2YQWE
# [0, 0, 0, 0, 0, 0, 0, 0, 0]

# %%
url = "https://api.helium.io/v1/hotspots/location/distance/?lat=36.871342&lon=-76.278701&distance=200"
dict1 = json.loads(requests.get(url).text)
# print(json.dumps(dict1, indent = 2))

minTime = []
maxTime = []
current_date = date.today()

for i in range(1,10):
    maxTime.append(current_date)
    priorDate = current_date-timedelta(days=7)
    minTime.append(priorDate)
    current_date = priorDate    


dataPerAddress = {}
for i in range(len(dict1['data'])):
    dataPerAddress[dict1['data'][i]['address']] = []
print(dataPerAddress.keys())

sum1 = 0
# sum2 = 0
# sum3 = 0
cursor = ''
for a in dataPerAddress:
    print("Current address: ", a)
    for t in range(len(minTime)):            
        url = "https://api.helium.io/v1/hotspots/" + a + "/rewards/?min_time="+str(minTime[t])+"T00:00:01Z&max_time="+str(maxTime[t])+"T23:59:59Z"


        dict = json.loads(requests.get(url).text)
        time.sleep(1)
        while "cursor" in dict:
            for i in range(len(dict['data'])):            
                sum1 = sum1 + dict['data'][i]['amount']
            cursor = dict['cursor']
            url = "https://api.helium.io/v1/hotspots/" + a + "/rewards/?min_time="+str(minTime[t])+"T00:00:01Z&max_time="+str(maxTime[t])+"T23:59:59Z"
            url = url + "&cursor=" + cursor
            dict = json.loads(requests.get(url).text)
            time.sleep(1)
        else:
            for i in range(len(dict['data'])):            
                sum1 = sum1 + dict['data'][i]['amount']

        dataPerAddress[a].append(sum1)
        sum1 = 0
    dataPerAddress[a].reverse()
    print(dataPerAddress[a])
    plt.plot(dataPerAddress[a])
    plt.show()
    plt.bar(range(9), dataPerAddress[a])
    plt.show()

        
dict.clear()
sum1=0
cursor=''
# Out:
# dict_keys(['11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w', '11yWfEwtSGLw3Vdh4iWgqnuKXRxELUkwN2v5wmB32UaRkq2YQWE'])
# Current address:  11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w
# [123146020, 135022846, 155679379, 100169604, 131137473, 147341661, 163370495, 108775276, 122564198]
# Current address:  11yWfEwtSGLw3Vdh4iWgqnuKXRxELUkwN2v5wmB32UaRkq2YQWE
# [0, 0, 0, 0, 0, 0, 0, 0, 0]

# %%
url = "https://api.helium.io/v1/hotspots/11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w/rewards/?min_time=2022-07-09T00:00:01Z&max_time=2022-07-12T23:59:59Z&cursor=eyJlbmRfYmxvY2siOjE0MzA4MTcsImJsb2NrIjoxNDM3MTAwLCJhbmNob3JfYmxvY2siOjE0MzcxMDB9"
dict1 = json.loads(requests.get(url).text)
print(json.dumps(dict1, indent = 2))

for i in range(len(dict1['data'])):            
    sum1 = sum1 + dict1['data'][i]['amount']
# Out:
# {
#   "data": [
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-12T13:38:19.000000Z",
#       "hash": "dTADyEshBWTlfn-j-kthWUNVtvIiPtvjjlIrHB8pM9Q",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1436932,
#       "amount": 786336,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-12T13:38:19.000000Z",
#       "hash": "dTADyEshBWTlfn-j-kthWUNVtvIiPtvjjlIrHB8pM9Q",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1436932,
#       "amount": 229,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-12T11:19:47.000000Z",
#       "hash": "oX0WHGAuzfxk1VtE_j5svblktoMCxJnj3RTstrprUtw",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1436798,
#       "amount": 1566327,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-12T10:42:37.000000Z",
#       "hash": "eyCNxyvNz-Jhha7aXAcgcvxtMa07fsNOzBK6K8Fhb18",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1436762,
#       "amount": 231,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-12T09:40:56.000000Z",
#       "hash": "yTbc3V6RRuWy-4lU-OM7qlBtAs8HiBdMokbKO3PTEqY",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1436696,
#       "amount": 635350,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_challengee",
#       "timestamp": "2022-07-12T09:02:43.000000Z",
#       "hash": "p3ry_QToWxaAMloRlyetUV1H4p7E6LuuDQRUE498ENI",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1436660,
#       "amount": 2529091,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-12T08:33:49.000000Z",
#       "hash": "m-MqPncORFFcfBc50K2nhMzWRKkw9CN-H_TPZPec9Yo",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1436628,
#       "amount": 1272063,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-12T08:03:54.000000Z",
#       "hash": "ubCH-xnGhbJQr-AIBaNfDpVwETcNwIKPycpYHi-5Lwg",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1436596,
#       "amount": 1173659,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-12T06:31:56.000000Z",
#       "hash": "gvskPjHEzybRGLT21jc0AYUQdPkKAl-k5c06on4NtLA",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1436497,
#       "amount": 114,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-12T04:15:43.000000Z",
#       "hash": "sWhKiJ3vXInpSy8CCZfw9qwDi6rCC9UIDPhbCwgPzdo",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1436365,
#       "amount": 368450,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-12T03:43:20.000000Z",
#       "hash": "lrrBPp0aUfZ36hmCAT2CHClR6T9w5Q7JewClQ7C660E",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1436333,
#       "amount": 461,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-12T02:38:03.000000Z",
#       "hash": "vfvGOCvqUcWCtfxbAixCvnZdJB6N5jWSbESqkLKX-WE",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1436269,
#       "amount": 1507249,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-11T23:23:58.000000Z",
#       "hash": "tyufN8GRi7ZNhiha_fxifoaxQryQEYopR9fDD_o5-fw",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1436065,
#       "amount": 678,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-11T20:40:36.000000Z",
#       "hash": "84KKkQsLC0wuEzMqNIkyRNwwc3xy_CCaH4Ir_OTKbGw",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1435884,
#       "amount": 759347,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-11T20:06:03.000000Z",
#       "hash": "vsbYEJXV3_jHbtrqeN--ZOBuyFzNGuRgGEPJTj2J9H0",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1435852,
#       "amount": 551,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-11T18:24:29.000000Z",
#       "hash": "36r2lZGZs9vjuTyHKU3ag86x0Ss_-9mH9vagJyAax9M",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1435757,
#       "amount": 790690,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-11T12:41:18.000000Z",
#       "hash": "e--trdoUp8LQBJPmg2YspXkiaNpwn-Kjk31zTaOULKU",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1435691,
#       "amount": 658,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-11T11:30:43.000000Z",
#       "hash": "r9SAWF20TXZU2y4YtTtq8g75LRI4Lva0nnzdlnUKCn0",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1435627,
#       "amount": 482355,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-11T10:31:55.000000Z",
#       "hash": "iDSbs0gooenzTk3Ph9XphMgjRmR5n6HxNlckijq5is4",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1435581,
#       "amount": 2228309,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-11T09:36:56.000000Z",
#       "hash": "eDKlUGTqYyc-i6_BVOLqGeb28EDUE_QrW5zRwtOTGic",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1435529,
#       "amount": 1511673,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-11T08:22:50.000000Z",
#       "hash": "_X-8A5o6tBQj2TCYaFrEf3WpH5L-qd5V3-aERhIQbSY",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1435465,
#       "amount": 335097,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-11T07:43:17.000000Z",
#       "hash": "6O9jzKzRx3XUXQso_r03DOJBiCdEOMmY9CYiSQXTXUs",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1435432,
#       "amount": 748618,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-11T07:00:50.000000Z",
#       "hash": "jSttjzKb01YKDR_iXSIdfbrcuL7K79ZZ7-9LmvYbvmM",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1435396,
#       "amount": 220,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-11T02:58:22.000000Z",
#       "hash": "T6TJ_bku35c3YbSr7E2RWz-RifaAhlAmhB-IpAEocxo",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1435183,
#       "amount": 907313,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-11T02:21:18.000000Z",
#       "hash": "MNYoiq5NAx6X6NKyMkyQ5UF_AtiUjkwbyOYOM2EOZA0",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1435151,
#       "amount": 326,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-11T02:21:18.000000Z",
#       "hash": "MNYoiq5NAx6X6NKyMkyQ5UF_AtiUjkwbyOYOM2EOZA0",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1435151,
#       "amount": 2153065,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-10T23:55:46.000000Z",
#       "hash": "DaopV0aIbEoqDLC9fcbTx9xWlI7dJGuhUQH2qj9RxTY",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1435018,
#       "amount": 1874260,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-10T21:29:53.000000Z",
#       "hash": "voKADjZGxRSdjUqzzLwzVHjI3rDAutoLdZ75MHSmhOw",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1434886,
#       "amount": 1294859,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-10T21:29:53.000000Z",
#       "hash": "voKADjZGxRSdjUqzzLwzVHjI3rDAutoLdZ75MHSmhOw",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1434886,
#       "amount": 424,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-10T17:27:39.000000Z",
#       "hash": "u9NSuvRDziMbvp1-I5VbL1fpk2BJGUI6_wgV_SrQd5k",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1434647,
#       "amount": 778137,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-10T15:45:51.000000Z",
#       "hash": "buM5hXQS7DB2QxWFkBULC9J-qVf-yANk447NZDtYs4A",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1434546,
#       "amount": 106,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-10T15:16:56.000000Z",
#       "hash": "COnYnXfxywox5mTR7e01jYLt0auJn9IQrRxRQh5NByk",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1434514,
#       "amount": 1136906,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-10T14:47:11.000000Z",
#       "hash": "85s489ro48dKKU0NvkYBVMUGVsobHfxPb3Ejx6_pwIQ",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1434482,
#       "amount": 510251,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-10T12:29:18.000000Z",
#       "hash": "TW_adnjZjPvVNaAF3iGtQeKSN8nLT7lx_GU6HM5WF6Y",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1434345,
#       "amount": 1591414,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-10T11:18:25.000000Z",
#       "hash": "FrIGvh1wddoQESjJPexrx6zFcEEmheneE8m4qf7OLhk",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1434279,
#       "amount": 1811671,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-10T10:01:14.000000Z",
#       "hash": "yjhftmSxoLOoLWuFreg971CMis5jUO2WYT1R8ort_C0",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1434199,
#       "amount": 2267790,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-10T10:01:14.000000Z",
#       "hash": "yjhftmSxoLOoLWuFreg971CMis5jUO2WYT1R8ort_C0",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1434199,
#       "amount": 313,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-10T05:52:29.000000Z",
#       "hash": "CoBUYlZ1CqBB0GbRsjlggRNesPQUq-oiSSh84NLESsM",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1433942,
#       "amount": 428,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-10T05:52:29.000000Z",
#       "hash": "CoBUYlZ1CqBB0GbRsjlggRNesPQUq-oiSSh84NLESsM",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1433942,
#       "amount": 1273943,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-10T04:22:48.000000Z",
#       "hash": "S5fofa5uuf4VryPKyRZDGzJMHbTkSzBw1iMIBQmrC68",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1433846,
#       "amount": 834060,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-10T03:48:17.000000Z",
#       "hash": "hhfPLE6A2xwb8PJ5gVOieHuyhLyBgaYSgyEJt6E0NQ8",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1433814,
#       "amount": 932806,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-10T00:44:26.000000Z",
#       "hash": "u9tKxcrCapUDgcW9RAc1uQp4gQDAUoIWLaTogyNrzDI",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1433634,
#       "amount": 1023790,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-10T00:14:03.000000Z",
#       "hash": "phYcuy7ExSQDOjmbGHAyU-4NJfV-NngaANSjf-s8QD8",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1433602,
#       "amount": 1356234,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-09T23:45:34.000000Z",
#       "hash": "RPAPYcG3zsbII8SgDE_ZPqBnse34oVf8StQNEP8UrvA",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1433570,
#       "amount": 1115212,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-09T23:17:09.000000Z",
#       "hash": "ky8YonL-_U1FVyXX6oYpyoE2i3W5VKeCFav3sYWv0Cc",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1433538,
#       "amount": 670142,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-09T21:43:47.000000Z",
#       "hash": "gQ5qV5hIJGaz0fCp2KAqKhWlWFwQ8Z0G774N1uIwB88",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1433438,
#       "amount": 208,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-09T20:00:53.000000Z",
#       "hash": "vUzNrfuIrKRLik0MQBdrS1mt-qgkHo9VqrGa4ByF5zI",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1433327,
#       "amount": 1326720,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-09T19:28:11.000000Z",
#       "hash": "Fzn5uFiW0sBPB2LIt1p_7a2QgFZE9DoDYyiHkLCQ2OI",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1433295,
#       "amount": 312,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-09T16:57:41.000000Z",
#       "hash": "hxCpCGfVY_68UhQ1wX8NnK3u0nOKC0AvnzphkFcWjNo",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1433140,
#       "amount": 1701075,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-09T15:07:38.000000Z",
#       "hash": "4njwpSvitptZcW2XBf8kfeL-XDgL2grsQt6WD-N6UF4",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1433041,
#       "amount": 1067637,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-09T15:07:38.000000Z",
#       "hash": "4njwpSvitptZcW2XBf8kfeL-XDgL2grsQt6WD-N6UF4",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1433041,
#       "amount": 107,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-09T13:51:46.000000Z",
#       "hash": "4W0WgFyKo7Y7EIlyhGI5qZWzNSX4w3ts6kECQaRFPjc",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1432971,
#       "amount": 565130,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-09T11:19:08.000000Z",
#       "hash": "OemSayTMKkO8pH7r_PrQc_8I7YaYBr2dPTxPI1UBx1g",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1432833,
#       "amount": 321,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_challengee",
#       "timestamp": "2022-07-09T09:27:43.000000Z",
#       "hash": "ql9nd5JLZKNIReBnzChqpwyk0fX18NyrM8DV3H3uk2w",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1432728,
#       "amount": 2554101,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-09T09:27:43.000000Z",
#       "hash": "ql9nd5JLZKNIReBnzChqpwyk0fX18NyrM8DV3H3uk2w",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1432728,
#       "amount": 1097209,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-09T08:53:05.000000Z",
#       "hash": "CJHvNAADeMG3WN6T6UeoKkh5shsKHthwe-ruBpkAzGs",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1432696,
#       "amount": 108,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-09T06:20:10.000000Z",
#       "hash": "ygGmLTMotlVC6YncRLULjD-cCheSp4dk0etRgiS2hcM",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1432545,
#       "amount": 1404794,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-09T04:37:05.000000Z",
#       "hash": "DYmN5VI_8FYO0Dehg_BA93-086YzZwO_jzSTi9GFh4A",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1432446,
#       "amount": 433,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-09T02:10:45.000000Z",
#       "hash": "wX3Dta0m6Cf0L4DoFzLu40r02tDWQleh-cjkC8pIY8Y",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1432305,
#       "amount": 3270890,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-09T00:32:06.000000Z",
#       "hash": "s52tMXvHSTGwO0LyyH1ex5dD7cTPSOFr8zDycbpR-VQ",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1432202,
#       "amount": 1682149,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-08T23:23:35.000000Z",
#       "hash": "r4tN3SMNNXlNSOA8VQG_vi-XMtu4ryRGQSNDuuU3Qi8",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1432138,
#       "amount": 214,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-08T22:47:08.000000Z",
#       "hash": "I-xH1BBOKcs1MQnRPZ67LX2Z-oQrxFz-I6a7_OYCeq0",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1432098,
#       "amount": 1715692,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-08T21:00:54.000000Z",
#       "hash": "4zBtEmxoC6F_pbqu7dh2YMpq5cPWfubSmKctS0VT9kU",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1431994,
#       "amount": 1157361,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-08T20:24:42.000000Z",
#       "hash": "PxId5iItj9cqFGawZ_A71tboVx4V5SRElb-Q3bcKYZE",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1431960,
#       "amount": 648084,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-08T19:06:50.000000Z",
#       "hash": "TsYOI31q3Ff5-AvqMzbszjw_sw_nHQYqotsTsAWnWww",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1431885,
#       "amount": 1147618,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-08T17:56:46.000000Z",
#       "hash": "cPi_Iu3fHNxJ3HaEnW_SNVw3dy22GNG_nzm4PpnONns",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1431818,
#       "amount": 874653,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-08T17:19:16.000000Z",
#       "hash": "SS6jLs9CtLelkKF_SmosdsyLGDBqGpuFZd2PvRCwfVw",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1431784,
#       "amount": 455765,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_challengee",
#       "timestamp": "2022-07-08T17:19:16.000000Z",
#       "hash": "SS6jLs9CtLelkKF_SmosdsyLGDBqGpuFZd2PvRCwfVw",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1431784,
#       "amount": 2699103,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-08T16:42:48.000000Z",
#       "hash": "FVP2gfhpTI7f45FPfNXfBwn7fFlEO7_bjKqSQi9YKg0",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1431750,
#       "amount": 108,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-08T15:25:37.000000Z",
#       "hash": "6z3-SFSne43TuZ8WfKMiFuWrXP5Uu4RPAi5vyD9HZJg",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1431684,
#       "amount": 1106687,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-08T11:36:26.000000Z",
#       "hash": "TsYjHhYcVg14bSC6DL9NY7-RA15QF2nlqI19e_MmUE4",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1431480,
#       "amount": 1145115,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-08T10:57:14.000000Z",
#       "hash": "3wwzf1_vDNP8u-L-9zH9yf4HhyNcgdR6DuGbzdQnOtM",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1431446,
#       "amount": 543,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-08T10:15:21.000000Z",
#       "hash": "ufybEaYrP4rOreDcpLbCdK4790bnT1MRT-yczFpNATo",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1431408,
#       "amount": 1670997,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-08T08:58:11.000000Z",
#       "hash": "dIBmBaGrqlqnN_XXySPRzcalgm4cD0iumC6KBeU3DDI",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1431338,
#       "amount": 2271685,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-08T06:35:16.000000Z",
#       "hash": "DDTiJn3oDOSVvMvg1-Y9a9lSnTkdZ5sxDkKSCob49RA",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1431203,
#       "amount": 316,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-08T04:08:57.000000Z",
#       "hash": "AOBSRh1XD704hxm6q1KxpxzKdfgHrPVUYKUDQuRMvug",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1431061,
#       "amount": 3101886,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-08T02:54:58.000000Z",
#       "hash": "cmqqfRQ1wBDTzowR8IIEhRnE19WkZN6XlXWEGUlcn40",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1430990,
#       "amount": 105,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-08T02:21:27.000000Z",
#       "hash": "oUEOxlLCbCEpRajnpURU3c4ZfDfwkCX2fS7SVEh_Okc",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1430959,
#       "amount": 2010940,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-08T01:08:35.000000Z",
#       "hash": "qFOc2MUiIYb6TqRXGWb1v1ZiFCNSo-WeNuUHBWUd-9E",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1430887,
#       "amount": 3846301,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "dc_rewards",
#       "timestamp": "2022-07-08T00:36:33.000000Z",
#       "hash": "U5o0WMesEFXWx3g5ysp9ejldG9bDMf0khDaD-rTPDbw",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1430855,
#       "amount": 320,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     },
#     {
#       "type": "poc_witness",
#       "timestamp": "2022-07-08T00:36:33.000000Z",
#       "hash": "U5o0WMesEFXWx3g5ysp9ejldG9bDMf0khDaD-rTPDbw",
#       "gateway": "11MrT1pSG7JZS51KBtieiHkAT9LCQvfkafa7qmEzcqoZVPc5M5w",
#       "block": 1430855,
#       "amount": 1272316,
#       "account": "14pqRVEWoui2YiNBd1uWfqc2isT5E6J8qRzJy984BCxbjEYu9iC"
#     }
#   ]
# }
# 786336
# 229
# 1566327
# 231
# 635350
# 2529091
# 1272063
# 1173659
# 114
# 368450
# 461
# 1507249
# 678
# 759347
# 551
# 790690
# 658
# 482355
# 2228309
# 1511673
# 335097
# 748618
# 220
# 907313
# 326
# 2153065
# 1874260
# 1294859
# 424
# 778137
# 106
# 1136906
# 510251
# 1591414
# 1811671
# 2267790
# 313
# 428
# 1273943
# 834060
# 932806
# 1023790
# 1356234
# 1115212
# 670142
# 208
# 1326720
# 312
# 1701075
# 1067637
# 107
# 565130
# 321
# 2554101
# 1097209
# 108
# 1404794
# 433
# 3270890
# 1682149
# 214
# 1715692
# 1157361
# 648084
# 1147618
# 874653
# 455765
# 2699103
# 108
# 1106687
# 1145115
# 543
# 1670997
# 2271685
# 316
# 3101886
# 105
# 2010940
# 3846301
# 320
# 1272316
